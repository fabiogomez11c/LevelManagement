# %%
from backtester.portfolio import Backtester

# %%
engine = Backtester()  # create the backtester
engine.run_backtest()  # run the algorithm

# %%
engine.create_report()  # simple report
# Out:
#                        Values
# Number of Trades    12.000000
# Total Return (%)  2540.362734
# Positive Trades      8.000000
# Winrate             66.666667
# Avg. Win           105.665102
# Avg. Loss          -26.020688

# %%
import pandas as pd

df = pd.DataFrame(engine.closed_trades)

# %%
df  # getting the trades
# Out:
#     UniqueID Entry Date  Entry Price  Type  Exit Date  Exit Price Exit Type  \
# 0          1 2012-07-22       8.5650  Long 2012-08-18     12.0700      Exit
# 1          2 2013-01-10      13.8400  Long 2013-03-06     43.2025      Exit
# 2          3 2013-03-25      73.6450  Long 2013-04-04    134.4675      Exit
# 3          4 2013-10-04     119.7550  Long 2013-11-19    584.5025      Exit
# 4          5 2013-11-22     750.7000  Long 2013-12-02    994.2900      Exit
# 5          6 2013-12-03    1045.0275  Long 2014-05-14    443.3600      Exit
# 6          7 2014-05-21     492.2975  Long 2014-11-08    343.9750      Exit
# 7          8 2015-02-28     251.3800  Long 2015-03-19    258.3375      Exit
# 8          9 2018-07-16    6540.7300  Long 2018-10-11   6311.5050      Exit
# 9         10 2019-10-26    9230.5750  Long 2020-02-17   9766.0325      Exit
# 10        11 2020-02-18    9950.3350  Long 2020-05-11   8669.2075      Exit
# ...
